# %%
# %reset -f

# %% [markdown]
# pip install pandas beancount matplotlib seaborn

# %%
from beancount.loader import load_file
import pandas as pd

entries, _, _ = load_file("./tab-data/ledger/dynamic.beancount")

txns = []
for entry in entries:
    if entry.__class__.__name__ == "Transaction":
        txn_id = id(entry)  # new unique ID for this transaction
        for posting in entry.postings:
            txns.append({
                "transaction_id": txn_id,
                "date": entry.date,
                "narration": entry.narration,
                "meta": entry.meta,
                "account": posting.account,
                "units": posting.units.number,
                "currency": posting.units.currency,
            })

df = pd.DataFrame(txns)

# %%
df
# Out:
#          transaction_id        date  ...   units currency
# 0       124767734339664  1970-01-01  ...    5.30      EUR
# 1       124767734339664  1970-01-01  ...   -5.30      EUR
# 2       124767734340336  1970-01-01  ...   -0.50      EUR
# 3       124767734340336  1970-01-01  ...    0.50      EUR
# 4       124767734341008  1970-01-01  ...  -11.80      EUR
# ...                 ...         ...  ...     ...      ...
# 104612  124767574668816  2026-01-22  ...       1     SODA
# 104613  124767574668816  2026-01-22  ...      -1    SNACK
# 104614  124767574668816  2026-01-22  ...       1    SNACK
# 104615  124767574668816  2026-01-22  ...    2.50      EUR
# 104616  124767574668816  2026-01-22  ...   -2.50      EUR
#
# [104617 rows x 7 columns]

# %% [markdown]
# # Examining columns

# %%
for column in df.columns:
    try:
        unique_count = df[column].nunique()
    except TypeError:
        unique_count = df[column].apply(lambda x: str(x)).nunique()
    print(f"{column}: {unique_count} unique values")
# Out:
# transaction_id: 25841 unique values
# date: 2173 unique values
# narration: 9474 unique values
# meta: 25841 unique values
# account: 92 unique values
# units: 865 unique values
# currency: 81 unique values

# %% [markdown]
# # Get rid of meta column

# %%
# Show first row
first_row = df.iloc[1000]
# print(first_row)

# Show shortened meta (first 100 chars)
meta_short = str(first_row['meta'])
print(meta_short)
# Out:
# {'filename': '/home/mateo/projects/bar-graphs/tab-data/ledger/imported-from-spacebar.beancount', 'lineno': 1713, '__tolerances__': {'EUR': Decimal('0.005')}}

# %% [markdown]
# From the meta we ONLY want the type of the purchase

# %%
df['type'] = df['meta'].apply(lambda m: m.get('type') if isinstance(m, dict) else None)
df = df.drop(columns=['meta'])
# Show results
df['type'].unique()
# Out:
# <StringArray>
# [nan, 'purchase', 'deposit', 'transfer']
# Length: 4, dtype: str

# %%
df
# Out:
#          transaction_id        date  ... currency      type
# 0       124767734339664  1970-01-01  ...      EUR       NaN
# 1       124767734339664  1970-01-01  ...      EUR       NaN
# 2       124767734340336  1970-01-01  ...      EUR       NaN
# 3       124767734340336  1970-01-01  ...      EUR       NaN
# 4       124767734341008  1970-01-01  ...      EUR       NaN
# ...                 ...         ...  ...      ...       ...
# 104612  124767574668816  2026-01-22  ...     SODA  purchase
# 104613  124767574668816  2026-01-22  ...    SNACK  purchase
# 104614  124767574668816  2026-01-22  ...    SNACK  purchase
# 104615  124767574668816  2026-01-22  ...      EUR  purchase
# 104616  124767574668816  2026-01-22  ...      EUR  purchase
#
# [104617 rows x 7 columns]

# %% [markdown]
# # Examining transactions
#
# Each transaction is a collection of postings.

# %%
postings_per_transaction = df.groupby("transaction_id").size().reset_index(name="num_postings")

postings_per_transaction = postings_per_transaction.sort_values(
    by='num_postings',
    ascending=False
).reset_index(drop=True)

top_id = postings_per_transaction.iloc[0]["transaction_id"]

postings_per_transaction
# Out:
#         transaction_id  num_postings
# 0      124767596323088            17
# 1      124767577492272            12
# 2      124767680516880            12
# 3      124767597147104            12
# 4      124767653314736            12
# ...                ...           ...
# 25836  124767734346384             2
# 25837  124767734345712             2
# 25838  124767734345040             2
# 25839  124767734344368             2
# 25840  124767734343696             2
#
# [25841 rows x 2 columns]

# %% [markdown]
# Let's look at all postings in this transaction

# %%
df[df["transaction_id"] == top_id]
# Out:
#         transaction_id        date  ...  currency      type
# 88846  124767596323088  2023-08-03  ...  COCKTAIL  purchase
# 88847  124767596323088  2023-08-03  ...  COCKTAIL  purchase
# 88848  124767596323088  2023-08-03  ...    GERMAN  purchase
# 88849  124767596323088  2023-08-03  ...    GERMAN  purchase
# 88850  124767596323088  2023-08-03  ...     DUVEL  purchase
# 88851  124767596323088  2023-08-03  ...     DUVEL  purchase
# 88852  124767596323088  2023-08-03  ...      CHIP  purchase
# 88853  124767596323088  2023-08-03  ...      CHIP  purchase
# 88854  124767596323088  2023-08-03  ...     WATER  purchase
# 88855  124767596323088  2023-08-03  ...     WATER  purchase
# 88856  124767596323088  2023-08-03  ...    HOODIE  purchase
# 88857  124767596323088  2023-08-03  ...    HOODIE  purchase
# 88858  124767596323088  2023-08-03  ...  PASSPORT  purchase
# 88859  124767596323088  2023-08-03  ...  PASSPORT  purchase
# 88860  124767596323088  2023-08-03  ...       EUR  purchase
# 88861  124767596323088  2023-08-03  ...       EUR  purchase
# 88862  124767596323088  2023-08-03  ...       EUR  purchase
#
# [17 rows x 7 columns]

# %% [markdown]
# # Get products

# %%
import yaml

# Load YAML and convert to DataFrame
with open("./tab-data/static/products.yml", "r") as f:
    price_data = yaml.safe_load(f)
df_products = pd.DataFrame(price_data)

# Expand the 'payback' dictionary into its own columns
if 'payback' in df_products.columns:
    payback_df = df_products['payback'].apply(lambda x: x if isinstance(x, dict) else {}).apply(pd.Series)
    payback_df.columns = [f'payback_{col}' for col in payback_df.columns]
    df_products = pd.concat([df_products.drop(columns=['payback']), payback_df], axis=1)

df_products
# Out:
#          name  price  ...               payback_account payback_amount
# 0        Soda    1.5  ...                           NaN            NaN
# 1     Cecemel    0.7  ...                           NaN            NaN
# 2       Fritz    2.5  ...                           NaN            NaN
# 3   Club Mate    3.0  ...                           NaN            NaN
# 4         Tea    0.5  ...                           NaN            NaN
# ..        ...    ...  ...                           ...            ...
# 63      Pizza    2.5  ...  Liabilities:Bar:Members:Yvan            1.5
# 64     SPRITE    2.0  ...                           NaN            NaN
# 65    Cha-Cha    0.5  ...                           NaN            NaN
# 66      Leffe    2.0  ...                           NaN            NaN
# 67      Orval    3.0  ...                           NaN            NaN
#
# [68 rows x 8 columns]

# %% [markdown]
# See all products where a payback is present. This means a member should be paid back every time an items is purchased of this kind.

# %%
df_products[df_products['payback_account'].notna()]
# Out:
#          name  price  ...                     payback_account payback_amount
# 11  Wristband    1.0  ...     Liabilities:Bar:Members:Marquis           0.50
# 14   Passport    2.5  ...        Liabilities:Bar:Members:Bart           1.20
# 15   Postcard    2.5  ...  Liabilities:Bar:Members:NewlineJar           1.00
# 59        ROM    1.0  ...     Liabilities:Bar:Members:Thequux           0.50
# 62  Ice Cream    1.0  ...        Liabilities:Bar:Members:Yvan           0.63
# 63      Pizza    2.5  ...        Liabilities:Bar:Members:Yvan           1.50
#
# [6 rows x 8 columns]

# %% [markdown]
# # Get recent values

# %%
df["date"] = pd.to_datetime(df["date"])  # Convert first
cutoff = pd.Timestamp.now() - pd.DateOffset(years=3)
recent_df = df[df["date"] >= cutoff]    # Then filter

# %%
recent_df
# Out:
#          transaction_id       date  ... currency      type
# 80472   124767669283056 2023-01-24  ...      EUR   deposit
# 80473   124767669283056 2023-01-24  ...      EUR   deposit
# 80474   124767669283616 2023-01-24  ...      EUR  transfer
# 80475   124767669283616 2023-01-24  ...      EUR  transfer
# 80476   124767669284400 2023-01-24  ...     SODA  purchase
# ...                 ...        ...  ...      ...       ...
# 104612  124767574668816 2026-01-22  ...     SODA  purchase
# 104613  124767574668816 2026-01-22  ...    SNACK  purchase
# 104614  124767574668816 2026-01-22  ...    SNACK  purchase
# 104615  124767574668816 2026-01-22  ...      EUR  purchase
# 104616  124767574668816 2026-01-22  ...      EUR  purchase
#
# [24145 rows x 7 columns]
